# %%
import torch
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import os
import pytorch_lightning as pl
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms

# %%
inp = torch.randn(10, 3, 8, 128, 128)

# %%
conv1 = nn.Conv3d(3, 8, (3, 5, 5))
conv2 = nn.Conv3d(8, 16, (3, 5, 5))
conv3 = nn.Conv3d(16, 24, (2, 5, 5))
conv4 = nn.Conv3d(24, 32, 2)

# %%
x = conv1(inp)
print("Shape after conv1:", x.shape)

x = conv2(x)
print("Shape after conv2:", x.shape)

x = conv3(x)
print("Shape after conv3:", x.shape)
# Out:
# Shape after conv1: torch.Size([10, 8, 6, 124, 124])
# Shape after conv2: torch.Size([10, 16, 4, 120, 120])
# Shape after conv3: torch.Size([10, 24, 3, 116, 116])
