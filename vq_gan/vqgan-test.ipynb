# %%
from lpips import download, URL_MAP, CKPT_MAP
import os
# Out:
# /Users/rateria/Code/cspca/vq-gan/lpips.py:83: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if name is not "vgg_lpips":
# /Users/rateria/anaconda3/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'dlopen(/Users/rateria/anaconda3/lib/python3.10/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c1017RegisterOperatorsD1Ev
#   Referenced from: <9B280146-BBD7-3F77-9873-F9740F2A5329> /Users/rateria/anaconda3/lib/python3.10/site-packages/torchvision/image.so
#   Expected in:     <A84DFEFF-287E-3B94-A7DB-731FA5F9CBBC> /Users/rateria/anaconda3/lib/python3.10/site-packages/torch/lib/libtorch_cpu.dylib'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
download(URL_MAP["vgg_lpips"], os.path.join("/Users/rateria/Code/cspca/vgg_lpips", CKPT_MAP["vgg_lpips"]))
# Out:
# 8.19kB [00:00, 35.2kB/s]

# %%
os.path.join(os.path.dirname(os.path.abspath(__file__)), "cache")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 os.path.join(os.path.dirname(os.path.abspath(__file__)), "cache")
#
# NameError: name '__file__' is not defined
